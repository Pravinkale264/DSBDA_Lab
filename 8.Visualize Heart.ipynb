# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/pravin264/Desktop/sfolder/DSBDA_JN/heart.csv")
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
#seaborn

# %%
#linechart
sns.lineplot(data=df, x='age', y='chol')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
#barplot
sns.barplot(data=df, x='sex', y='trtbps', hue='output')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='trtbps'>

# %%
# sns.heatmap(df.corr())

# %%
# sns.heatmap(data=df, annot=True, fmt='.2f', cmap='YlGnBu')

# %%
#heatmap

df.groupby('cp').thall.value_counts()
# Out:
# cp  thall
# 0   3        78
#     2        52
#     1        12
#     0         1
# 1   2        39
#     3         9
#     1         2
# 2   2        62
#     3        22
#     1         2
#     0         1
# 3   2        13
#     3         8
#     1         2
# Name: thall, dtype: int64

# %%
new_df =(
    df
     .groupby('cp')
     .thall
     .value_counts()
     .unstack()
     .fillna(0)
)
new_df
# Out:
# thall    0     1     2     3
# cp
# 0      1.0  12.0  52.0  78.0
# 1      0.0   2.0  39.0   9.0
# 2      1.0   2.0  62.0  22.0
# 3      0.0   2.0  13.0   8.0

# %%
sns.heatmap(new_df, annot=True, fmt='.1f')
# Out:
# <AxesSubplot:xlabel='thall', ylabel='cp'>

# %%
# df.corr()

# %%
#scatterplot
sns.scatterplot(data=df, x='age', y='chol', hue='output')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
#histogram
sns.histplot(data=df, x='chol' )
# Out:
# <AxesSubplot:xlabel='chol', ylabel='Count'>

# %%
#boxplot
sns.boxplot(data=df, x='chol')
# Out:
# <AxesSubplot:xlabel='chol'>

# %%
df.chol.describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
sns.violinplot(data=df, x='chol')
# Out:
# <AxesSubplot:xlabel='chol'>

# %%
# sns.violinplot(data=df, x='sex', y='output')

# %%
#matplotlib

# %%
#lineplot
plt.plot(df.chol)
plt.show()

# %%
# plt.scatter(df['thalachh'], df['age'])
# plt.show()

# %%
plt.scatter(df['thalachh'], df['age'])
plt.show()

# %%
#barplot
df2 = pd.DataFrame(df['cp'].value_counts())
df2
# Out:
#     cp
# 0  143
# 2   87
# 1   50
# 3   23

# %%
plt.bar(df2.index, df2['cp'])
plt.show()

# %%
plt.imshow(new_df)
plt.show()

# %%
plt.hist(df.age)
plt.show()

# %%
plt.boxplot(df.chol, vert=False)
plt.show()

# %%
plt.violinplot(df.chol, vert=False)
plt.show()
