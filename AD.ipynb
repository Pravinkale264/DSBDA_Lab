# %%
# Assignment B - 1

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/home/pravin264/Desktop/sfolder/DSBDA_JN/adult_dataset.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.shape
# Out:
# (48842, 15)

# %%
#Subset-1
df1=df[['age','workclass','education','gender']].loc[0:15]
df1
# Out:
#     age         workclass     education  gender
# 0    25           Private          11th    Male
# 1    38           Private       HS-grad    Male
# 2    28         Local-gov    Assoc-acdm    Male
# 3    44           Private  Some-college    Male
# 4    18                 ?  Some-college  Female
# 5    34           Private          10th    Male
# 6    29                 ?       HS-grad    Male
# 7    63  Self-emp-not-inc   Prof-school    Male
# 8    24           Private  Some-college  Female
# 9    55           Private       7th-8th    Male
# 10   65           Private       HS-grad    Male
# 11   36       Federal-gov     Bachelors    Male
# 12   26           Private       HS-grad  Female
# 13   58                 ?       HS-grad    Male
# 14   48           Private       HS-grad    Male
# 15   43           Private       Masters    Male

# %%
#Subset-2
df2=df[['age','workclass','education','gender']].loc[16:30]
df2
# Out:
#     age         workclass     education  gender
# 16   20         State-gov  Some-college    Male
# 17   43           Private       HS-grad  Female
# 18   37           Private       HS-grad  Female
# 19   40           Private     Doctorate    Male
# 20   34           Private     Bachelors    Male
# 21   34           Private  Some-college  Female
# 22   72                 ?       7th-8th  Female
# 23   25           Private     Bachelors    Male
# 24   25           Private     Bachelors    Male
# 25   45  Self-emp-not-inc       HS-grad    Male
# 26   22           Private       HS-grad    Male
# 27   23           Private       HS-grad    Male
# 28   54           Private       HS-grad    Male
# 29   32  Self-emp-not-inc  Some-college    Male
# 30   46         State-gov  Some-college    Male

# %%
# Merge Data 
mergedata = pd.concat([df1,df2])
mergedata
# Out:
#     age         workclass     education  gender
# 0    25           Private          11th    Male
# 1    38           Private       HS-grad    Male
# 2    28         Local-gov    Assoc-acdm    Male
# 3    44           Private  Some-college    Male
# 4    18                 ?  Some-college  Female
# 5    34           Private          10th    Male
# 6    29                 ?       HS-grad    Male
# 7    63  Self-emp-not-inc   Prof-school    Male
# 8    24           Private  Some-college  Female
# 9    55           Private       7th-8th    Male
# 10   65           Private       HS-grad    Male
# 11   36       Federal-gov     Bachelors    Male
# 12   26           Private       HS-grad  Female
# 13   58                 ?       HS-grad    Male
# 14   48           Private       HS-grad    Male
# 15   43           Private       Masters    Male
# 16   20         State-gov  Some-college    Male
# 17   43           Private       HS-grad  Female
# 18   37           Private       HS-grad  Female
# ...

# %%
# Sort Data
sort_values=df.sort_values('age',ascending=True)
sort_values
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 32598   17           Private  133449           9th                5
# 29817   17  Self-emp-not-inc  181317          10th                6
# 36580   17           Private  147339          10th                6
# 26409   17           Private  186677          11th                7
# 19520   17                 ?  110998  Some-college               10
# ...    ...               ...     ...           ...              ...
# 12446   90           Private  347074  Some-college               10
# 19172   90           Private  171956  Some-college               10
# 8982    90           Private  225063       HS-grad                9
# 28277   90           Private   40388     Bachelors               13
# 899     90           Private  149069    Assoc-acdm               12
#
#            marital-status         occupation   relationship  \
# 32598       Never-married      Other-service      Own-child
# ...

# %%
# Transposing Data
df.transpose()
# Out:
#                              0                   1                   2      \
# age                             25                  38                  28
# workclass                  Private             Private           Local-gov
# fnlwgt                      226802               89814              336951
# education                     11th             HS-grad          Assoc-acdm
# educational-num                  7                   9                  12
# marital-status       Never-married  Married-civ-spouse  Married-civ-spouse
# occupation       Machine-op-inspct     Farming-fishing     Protective-serv
# relationship             Own-child             Husband             Husband
# race                         Black               White               White
# gender                        Male                Male                Male
# capital-gain                     0                   0                   0
# ...

# %%
# Shape and Reshape
df.shape
# Out:
# (48842, 15)

# %%
# Reshape
pivot_table = pd.pivot_table(df,index=['age','education'],values='hours-per-week')
print(pivot_table)
# Out:
#                   hours-per-week
# age education
# 17  10th               21.363636
#     11th               20.044944
#     12th               20.597015
#     5th-6th            32.666667
#     7th-8th            28.800000
# ...                          ...
# 90  Bachelors          31.666667
#     HS-grad            38.000000
#     Masters            57.800000
#     Prof-school        59.000000
#     Some-college       27.375000
#
# [1007 rows x 1 columns]
